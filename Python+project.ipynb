# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlp
import seaborn as sns

# %%
df=pd.read_csv("youtube_dislike_dataset.csv")
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# ##  Q1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
#printing top 5 rows
df.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
#printing Bottom 5 rows
df.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# ## Q2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
#checking info of the dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
#Checking Data type of the dataset.
df.dtypes
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# comments         object
# dtype: object

# %%
#checking shape of the dataframe.
df.shape
# Out:
# (37422, 12)

# %% [markdown]
# ### Inference

# %% [raw]
# The dataframe contains a total of 37,422 rows and 12 columns.The dataframe contains 12 variables and only the comments column has Null Values.There are 4 columns (view_count, likes, dislikes, comment_count) contain numerical data
# of type int64, while the remaining columns contain string data of type object.

# %% [markdown]
# ## Q3. Check for the Percentage of the missing values and drop or impute them.

# %%
#checking the percentage of the missing values 
df.isnull().mean()*100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
#droping the rows that contain missing values
df.dropna(inplace= True)
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
#again checking the missing values 
df.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %% [markdown]
# ## Q4. Check the statistical summary of both numerical and categorical columns and write your inferences

# %%
# Checking the statiscal summary of both numerical and categorical columns
df.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
df.describe(include = "all").T
# Out:
#                  count unique  \
# video_id         37264  37264
# title            37264  36958
# channel_id       37264  10891
# channel_title    37264  10813
# published_at     37264  36617
# view_count     37264.0    NaN
# likes          37264.0    NaN
# dislikes       37264.0    NaN
# comment_count  37264.0    NaN
# tags             37264  28705
# description      37264  35479
# comments         37264  37264
#
#                                                              top  freq  \
# video_id                                             --0bCF-iK2E     1
# title                                                        www    21
# channel_id                              UCNAf1k0yIjyGu3k9BwAg3lg   533
# channel_title                                Sky Sports Football   533
# published_at                                 2020-10-16 04:00:10     6
# view_count                                                   NaN   NaN
# ...

# %%
df.describe(include=["object"])
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description  \
# count                 37264  37264       37264
# unique                36617  28705       35479
# top     2020-10-16 04:00:10
# freq                      6   3808         587
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %% [markdown]
# ### Inference

# %% [raw]
# The numerical columns include view_count, likes, dislikes, and comment_count. The statistical summary for these numerical data types offers descriptive insights into our dataset. Examining the mean of these numerical columns provides valuable information, while understanding the quartiles helps to analyze the data distribution. On the other hand, the categorical column contributes to a comprehensive understanding of the dataset.

# %% [markdown]
# ## Q5. Convert datatype of column published_at from object to pandas datetime.

# %%
df["published_at"]
# Out:
# 0        2021-07-01 10:00:00
# 1        2021-06-10 16:00:00
# 2        2021-09-20 01:03:32
# 3        2021-03-03 10:00:17
# 4        2021-12-07 13:00:00
#                 ...
# 37417    2021-02-12 05:03:49
# 37418    2021-01-16 05:39:05
# 37419    2021-06-02 09:00:10
# 37420    2020-10-20 20:59:30
# 37421    2021-05-23 21:00:31
# Name: published_at, Length: 37264, dtype: object

# %%
df["published_at"] = pd.to_datetime(df["published_at"])
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
df.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %% [markdown]
# ## Q6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df['published_month']=df['published_at'].dt.month
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# ## Q7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and soon....
# .

# %%
df['published_month'].replace({1:"January",2: 'February',3:'March',4: 'April',5: 'May',6: 'June',7: 'July',8: 'August',9: 'September',10: 'October',11: 'November',12: 'December'},inplace=True)
df[['published_at','published_month']]
# Out:
#              published_at published_month
# 0     2021-07-01 10:00:00            July
# 1     2021-06-10 16:00:00            June
# 2     2021-09-20 01:03:32       September
# 3     2021-03-03 10:00:17           March
# 4     2021-12-07 13:00:00        December
# ...                   ...             ...
# 37417 2021-02-12 05:03:49        February
# 37418 2021-01-16 05:39:05         January
# 37419 2021-06-02 09:00:10            June
# 37420 2020-10-20 20:59:30         October
# 37421 2021-05-23 21:00:31             May
#
# [37264 rows x 2 columns]

# %% [markdown]
# ## Q8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count..

# %%
#Grouping month and sorting descending video count (using pivot table)
df.pivot_table(values='video_id',index='published_month',aggfunc='count').sort_values('video_id',ascending=False)
# Out:
#                  video_id
# published_month
# October              4976
# September            4854
# November             4821
# August               4250
# December             3063
# July                 2331
# June                 2305
# March                2248
# February             2125
# April                2119
# January              2099
# May                  2073

# %% [markdown]
# ## Q9. Find the count of unique video_id, channel_id and channel_title.

# %%
#Getting count of the unique of video_id, channel_id and channel_title.
unique_video_id= df['video_id'].nunique()
unique_channel_id = df['channel_id'].nunique()
unique_channel_title = df['channel_title'].nunique()

#printing the result
print("Total Unique video id is " ,unique_channel_id)
print("Total Unique channel id is ",unique_video_id)
print("Total Unique channel title is", unique_channel_title)
# Out:
# Total Unique video id is  10891
# Total Unique channel id is  37264
# Total Unique channel title is 10813

# %% [markdown]
# ## Q10. Find the top10 channel names having the highest number of videos in the dataset and the bottom having lowest number of videos.s.

# %% [markdown]
# ### Top 10

# %%
#Using Pivot table to group month and sorting by video count for Top 10
df.pivot_table(index= 'channel_title', values='video_id', aggfunc='count').sort_values('video_id',ascending= False).head(10)
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %% [markdown]
# ### Bottom 10

# %%
#Using Pivot table to group month and sorting by video count for Bottom 10
df.pivot_table(index= 'channel_title', values='video_id', aggfunc='count').sort_values('video_id',ascending= False).tail(10)
# Out:
#                  video_id
# channel_title
# Karikku Tuned           1
# Karen Bustillos         1
# Karen Aslanyan          1
# Karchez                 1
# Karate Combat           1
# Kaptain Kuba            1
# Kanye West              1
# Kannur kitchen          1
# Kannada Cinema          1
# zoom                    1

# %% [markdown]
# ## Q11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
#using pivot table to find to which video got maximium no of likes.
df.pivot_table(index= 'title', values='likes', aggfunc='max').sort_values('likes',ascending= False).head(1)
# Out:
#                                   likes
# title
# BTS () 'Dynamite' Official MV  31837675

# %%
#using pivot table to find to which video got minimium no of likes.
df.pivot_table(index= 'title', values='likes', aggfunc='max').sort_values('likes',ascending= False).tail(1)
# Out:
#                                likes
# title
# Leading the Charge | Circle K     22

# %% [markdown]
# ###  Inference

# %% [raw]
# The most liked video is "BTS () 'Dynamite' Official MV", having 31837675 likes
# The lowest liked video is "Leading the Charge | Circle K", having 22 likes.

# %% [markdown]
# ##  Q12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences..

# %%
#using pivot table to find to which video got maximium no of dislikes.
df.pivot_table(index= 'title', values='dislikes', aggfunc='max').sort_values('dislikes',ascending= False).head(1)
# Out:
#                                      dislikes
# title
# Cuties | Official Trailer | Netflix   2397733

# %%
#using pivot table to find to which video got minimium no of dislikes.
df.pivot_table(index= 'title', values='dislikes', aggfunc='max').sort_values('dislikes',ascending= False).tail(1)
# Out:
#                                         dislikes
# title
# Tims For Good: A Taste Of The Familiar         3

# %% [markdown]
# ### Inference

# %% [raw]
# The video having maximum number of dislikes(2397733) is "Cuties | Official Trailer | Netflix()"
# The video having minimum number of dislikes(3) is "Tims For Good: A Taste Of The Familiar ".

# %% [markdown]
# ## Q13.Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot..

# %%
import matplotlib.pyplot as plt
new = df[['view_count','dislikes']]

# %% [markdown]
# ### Correlation

# %%
new.corr()
# Out:
#             view_count  dislikes
# view_count    1.000000  0.684576
# dislikes      0.684576  1.000000

# %% [markdown]
# ### Covariance

# %%
new.cov()
# Out:
#               view_count      dislikes
# view_count  5.911238e+14  5.118389e+11
# dislikes    5.118389e+11  9.456817e+08

# %%
plt.figure(figsize=(7,5))
plt.ticklabel_format(style='sci')
plt.scatter(new['view_count'],new['dislikes'])
plt.title('View_count v/s Dislikes')
plt.xlabel('view_count')
plt.ylabel('dislikes')
plt.style.use(style='ggplot')
plt.show()

# %% [markdown]
# ### Inference

# %% [raw]
# The correlation between views and dislikes is 0.684. From the co-rrelation and covariance matrix we can say that they have a positive relation between each other.(if one increases other also increases and vice versa).Scatter plot also implies
# the same.

# %% [markdown]
# ## Q14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January..

# %%
## Filter information of the  videos published in January
jan=df[df['published_month']=='January']
jan
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
#total no of published videos in january
jan['published_month'].count()
# Out:
# 2099

# %% [raw]
# Total no of videos are published in january is 2099
